# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ds= pd.read_csv('planilharisco.csv' , delimiter=';', encoding='latin-1')

# %%
ds
# Out:
#        Nome      função    tipo emprego  tempo empresa  \
# 0     Maria    Analista  Contrato 1 ano              0
# 1      Luiz     Tecnico         publico              2
# 2       Ana   Professor             clt              1
# 3   Marcelo    Analista         publico              5
# 4    Renato  Manutenção  Contrato 1 ano              3
# 5    Marcia   professor         publico              2
# 6     Julio    Analista             clt              4
# 7    Amanda  Manutenção  Contrato 1 ano              2
# 8     Fabio  Manutenção  Contrato 1 ano              3
# 9      João     Tecnico             clt              7
# 10   Marcio    Analista         publico              2
# 11  Jessica   professor         publico              3
#
#     numero de emprestimos feitos
# 0                              2
# 1                              1
# 2                              0
# 3                              1
# 4                              5
# 5                              2
# 6                              2
# 7                              0
# 8                              2
# 9                              3
# 10                             2
# 11                             3

# %%
def riscoTipoEmprego(tipo):
    if tipo =='publico':
        return  2 *3  #pontuação x peso
    if tipo =='clt':
        return  3 *3
    if tipo =='Contrato 1 ano':
        return  5 *3
    else:
        return  5 *3

# %%
def riscoTempoEmpresa(tempo):
    if tempo == 0 or tempo == 1:
        return 5 *2
    if tempo == 2 or tempo == 3:
        return 4 *2
    if tempo == 4 or tempo == 5:
        return 3 *2
    if tempo == 6 or tempo == 7:
        return 2 *2
    if tempo > 7:
        return 1 *2
    else:
        return 5 *2

# %%
def riscoQtdEmprestimo(qtd):
    if qtd == 0 or qtd == 1:
        return 5 *2 
    if qtd == 2 or qtd == 3:
        return 4 *2 
    if qtd == 4 or qtd == 5:
        return 3 *2 
    if qtd >= 6:
        return 2 *2 
    else:
        return  5 *2

# %%
ds['Risco_TipoEmprego'] = ds['tipo emprego'].apply(riscoTipoEmprego)

# %%
ds.head(5)
# Out:
#       Nome      função    tipo emprego  tempo empresa  \
# 0    Maria    Analista  Contrato 1 ano              0
# 1     Luiz     Tecnico         publico              2
# 2      Ana   Professor             clt              1
# 3  Marcelo    Analista         publico              5
# 4   Renato  Manutenção  Contrato 1 ano              3
#
#    numero de emprestimos feitos  Risco_TipoEmprego  Risco_Tempo_Empresa  \
# 0                             2                 15                   10
# 1                             1                  6                    8
# 2                             0                  9                   10
# 3                             1                  6                    6
# 4                             5                 15                    8
#
#    Risco_Qtd_emprestimo  Risco_
# 0                     4      29
# 1                     5      19
# 2                     5      24
# 3                     5      17
# 4                     3      26

# %%
ds['Risco_Tempo_Empresa'] = ds['tempo empresa'].apply(riscoTempoEmpresa)

# %%
ds
# Out:
#        Nome      função    tipo emprego  tempo empresa  \
# 0     Maria    Analista  Contrato 1 ano              0
# 1      Luiz     Tecnico         publico              2
# 2       Ana   Professor             clt              1
# 3   Marcelo    Analista         publico              5
# 4    Renato  Manutenção  Contrato 1 ano              3
# 5    Marcia   professor         publico              2
# 6     Julio    Analista             clt              4
# 7    Amanda  Manutenção  Contrato 1 ano              2
# 8     Fabio  Manutenção  Contrato 1 ano              3
# 9      João     Tecnico             clt              7
# 10   Marcio    Analista         publico              2
# 11  Jessica   professor         publico              3
#
#     numero de emprestimos feitos  Risco_TipoEmprego  Risco_Tempo_Empresa
# 0                              2                 15                   10
# 1                              1                  6                    8
# 2                              0                  9                   10
# 3                              1                  6                    6
# 4                              5                 15                    8
# 5                              2                  6                    8
# 6                              2                  9                    6
# 7                              0                 15                    8
# 8                              2                 15                    8
# 9                              3                  9                    4
# 10                             2                  6                    8
# 11                             3                  6                    8

# %%
ds['Risco_Qtd_emprestimo'] = ds['numero de emprestimos feitos'].apply(riscoQtdEmprestimo)

# %%
ds
# Out:
#        Nome      função    tipo emprego  tempo empresa  \
# 0     Maria    Analista  Contrato 1 ano              0
# 1      Luiz     Tecnico         publico              2
# 2       Ana   Professor             clt              1
# 3   Marcelo    Analista         publico              5
# 4    Renato  Manutenção  Contrato 1 ano              3
# 5    Marcia   professor         publico              2
# 6     Julio    Analista             clt              4
# 7    Amanda  Manutenção  Contrato 1 ano              2
# 8     Fabio  Manutenção  Contrato 1 ano              3
# 9      João     Tecnico             clt              7
# 10   Marcio    Analista         publico              2
# 11  Jessica   professor         publico              3
#
#     numero de emprestimos feitos  Risco_TipoEmprego  Risco_Tempo_Empresa  \
# 0                              2                 15                   10
# 1                              1                  6                    8
# 2                              0                  9                   10
# 3                              1                  6                    6
# 4                              5                 15                    8
# 5                              2                  6                    8
# 6                              2                  9                    6
# 7                              0                 15                    8
# 8                              2                 15                    8
# 9                              3                  9                    4
# 10                             2                  6                    8
# 11                             3                  6                    8
#
#     Risco_Qtd_emprestimo
# 0                      4
# 1                      5
# 2                      5
# 3                      5
# 4                      3
# 5                      4
# 6                      4
# 7                      5
# 8                      4
# 9                      4
# 10                     4
# 11                     4

# %%
ds['Risco_'] = ds['Risco_TipoEmprego']+ ds['Risco_Tempo_Empresa']+ ds['Risco_Qtd_emprestimo']

# %%
ds
# Out:
#        Nome      função    tipo emprego  tempo empresa  \
# 0     Maria    Analista  Contrato 1 ano              0
# 1      Luiz     Tecnico         publico              2
# 2       Ana   Professor             clt              1
# 3   Marcelo    Analista         publico              5
# 4    Renato  Manutenção  Contrato 1 ano              3
# 5    Marcia   professor         publico              2
# 6     Julio    Analista             clt              4
# 7    Amanda  Manutenção  Contrato 1 ano              2
# 8     Fabio  Manutenção  Contrato 1 ano              3
# 9      João     Tecnico             clt              7
# 10   Marcio    Analista         publico              2
# 11  Jessica   professor         publico              3
#
#     numero de emprestimos feitos  Risco_TipoEmprego  Risco_Tempo_Empresa  \
# 0                              2                 15                   10
# 1                              1                  6                    8
# 2                              0                  9                   10
# 3                              1                  6                    6
# 4                              5                 15                    8
# 5                              2                  6                    8
# 6                              2                  9                    6
# 7                              0                 15                    8
# 8                              2                 15                    8
# 9                              3                  9                    4
# 10                             2                  6                    8
# 11                             3                  6                    8
#
#     Risco_Qtd_emprestimo  Risco_
# 0                      8      33
# 1                     10      24
# 2                     10      29
# 3                     10      22
# 4                      6      29
# 5                      8      22
# 6                      8      23
# 7                     10      33
# 8                      8      31
# 9                      8      21
# 10                     8      22
# 11                     8      22

# %%
#ordenando pelo risco
ds.sort_values(by='Risco_',ascending=False)
# Out:
#        Nome      função    tipo emprego  tempo empresa  \
# 0     Maria    Analista  Contrato 1 ano              0
# 7    Amanda  Manutenção  Contrato 1 ano              2
# 8     Fabio  Manutenção  Contrato 1 ano              3
# 2       Ana   Professor             clt              1
# 4    Renato  Manutenção  Contrato 1 ano              3
# 1      Luiz     Tecnico         publico              2
# 6     Julio    Analista             clt              4
# 3   Marcelo    Analista         publico              5
# 5    Marcia   professor         publico              2
# 10   Marcio    Analista         publico              2
# 11  Jessica   professor         publico              3
# 9      João     Tecnico             clt              7
#
#     numero de emprestimos feitos  Risco_TipoEmprego  Risco_Tempo_Empresa  \
# 0                              2                 15                   10
# 7                              0                 15                    8
# 8                              2                 15                    8
# 2                              0                  9                   10
# 4                              5                 15                    8
# 1                              1                  6                    8
# 6                              2                  9                    6
# 3                              1                  6                    6
# 5                              2                  6                    8
# 10                             2                  6                    8
# 11                             3                  6                    8
# 9                              3                  9                    4
#
#     Risco_Qtd_emprestimo  Risco_
# 0                      8      33
# 7                     10      33
# 8                      8      31
# 2                     10      29
# 4                      6      29
# 1                     10      24
# 6                      8      23
# 3                     10      22
# 5                      8      22
# 10                     8      22
# 11                     8      22
# 9                      8      21

# %%
a= list(ds.groupby('Risco_')['Nome'])

# %%
risco = pd.DataFrame(a,columns=['Risco_','Nome'])
