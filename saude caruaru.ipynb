# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv('saude1.CSV' ,delimiter=';' , encoding='ISO-8859-1')

# %%
ds.head()
# Out:
#                                    Unidade Operativa Tipo  Turma  \
# 0  13 - SENAC - UNIDADE DE EDUCAÇÃO PROFISSIONAL ...     Técnico
# 1  13 - SENAC - UNIDADE DE EDUCAÇÃO PROFISSIONAL ...     Técnico
# 2  13 - SENAC - UNIDADE DE EDUCAÇÃO PROFISSIONAL ...     Técnico
# 3  13 - SENAC - UNIDADE DE EDUCAÇÃO PROFISSIONAL ...     Técnico
# 4  13 - SENAC - UNIDADE DE EDUCAÇÃO PROFISSIONAL ...     Técnico
#
#                                         Tipo Curso Segmento  \
# 0  Habilitação Profissional Técnica de Nível Médio    Saúde
# 1  Habilitação Profissional Técnica de Nível Médio    Saúde
# 2  Habilitação Profissional Técnica de Nível Médio    Saúde
# 3  Habilitação Profissional Técnica de Nível Médio    Saúde
# 4  Habilitação Profissional Técnica de Nível Médio    Saúde
#
#                 Eixo                  Curso                     Nome Aluno  \
# 0  Ambiente e Saúde   Técnico em Enfermagem         ROSANA DE BARROS RAMOS
# ...

# %%
plt.rcParams["figure.figsize"] = (10,10)
plt.rcParams['legend.fontsize'] = 2
ds['Sexo'].value_counts().head(30).plot(kind='barh')

# %%
plt.rcParams["figure.figsize"] = (10,8)

ds['Escolaridade'].value_counts().head(30).plot(kind='barh')

# %%
plt.rcParams["figure.figsize"] = (10,10)

ds['Estado Civil'].value_counts().head(30).plot(kind='barh')

# %%
plt.rcParams["figure.figsize"] = (10,10)

ds['Raça'].value_counts().head(30).plot(kind='barh')

# %%
plt.rcParams["figure.figsize"] = (10,10)

ds['Curso'].value_counts().head(30).plot(kind='barh')

# %%
plt.rcParams["figure.figsize"] = (10,10)

ds['Idade'].value_counts().plot(kind='barh')

# %%
plt.rcParams["figure.figsize"] = (10,10)

ds['Unidade Operativa'].value_counts().plot(kind='barh')
