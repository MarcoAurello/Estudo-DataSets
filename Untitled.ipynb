# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
levantamento = pd.read_csv('xplanilha221118.CSV' ,delimiter=';' , encoding='ISO-8859-1')

# %%
print("Quantidade de bolsas Registradas: ",len(levantamento))
# Out:
# Quantidade de bolsas Registradas:  624

# %%
levantamento.head(5)
# Out:
#   Envio do formulario data/hora  mes   Ano Endereço de e-mail  \
# 0                    11/05/2018    5  2018                NaN
# 1                    12/03/2018    3  2018                NaN
# 2                    04/06/2018    6  2018                NaN
# 3                    28/03/2018    3  2018                NaN
# 4                    06/04/2018    4  2018                NaN
#
#   Nome do solicitante Unidade/Área operacional Tipo de serviço  \
# 0              gercom                   GERCOM             NaN
# 1              gercom                   GERCOM             NaN
# 2                 NaN                      GAO             NaN
# 3              monica                     DIOP             NaN
# 4             luciana                   GERCOM           Curso
#
#                          Título do Projeto/Atividade  \
# 0             \nImplantação do Portal do PSG no site
# 1                   Stand by statement sobre o Senac
# ...

# %%
plt.rcParams["figure.figsize"] = (10,5)
plt.rcParams['legend.fontsize'] = 5
levantamento['N° serviços do projeto'].value_counts().plot(kind='barh')

# %%
levantamento['O projeto tem parceiros?']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
#        ..
# 606   NaN
# 607   NaN
# 608   NaN
# 609   NaN
# 610   NaN
# 611   NaN
# 612   NaN
# 613   NaN
# 614   NaN
# 615   NaN
# 616   NaN
# 617   NaN
# 618   NaN
# 619   NaN
# 620   NaN
# 621   NaN
# 622   NaN
# 623   NaN
# 624   NaN
# 625   NaN
# 626   NaN
# 627   NaN
# 628   NaN
# 629   NaN
# 630   NaN
# 631   NaN
# 632   NaN
# 633   NaN
# 634   NaN
# 635   NaN
# Name: O projeto tem parceiros?, Length: 636, dtype: float64

# %%
levantamento.columns
# Out:
# Index(['Envio do formulario data/hora', 'mes', 'Ano', 'Endereço de e-mail',
#        'Nome do solicitante', 'Unidade/Área operacional', 'Tipo de serviço',
#        'Título do Projeto/Atividade', 'Unnamed: 8', 'O projeto já existe? ',
#        'Data da atividade', 'Caso sim, quais são os parceiros',
#        'Data da atividade.1', 'Que tipo de serviço você gostaria?',
#        'Link arquivos e informações', 'Mídias Sociais', 'P midia',
#        'Cobertura jornalística', 'p cobertura', 'Matéria Site', 'p materia',
#        'Adesivos Diversos', 'p adesivo', 'Banner Digital', 'p baner',
#        'Unnamed: 25', 'Unnamed: 26', 'Camiseta/Bolsas/Brindes', 'Unnamed: 28',
#        'Cartaz', 'p cartaz', 'Panfleto', 'p panfleto', 'Faixa', 'p faixa',
#        'email', 'p email', 'Placas sinalização', 'p sinalizacao', 'total',
#        'N° serviços do projeto', 'Data de Início da Produção \n(02)',
#        'Data de envio para Revisão \n(03)',
#        'Data de recebimento da Revisão \n(04)',
# ...

# %%
print(levantamento.corr())
# Out:
#                                                          mes  Ano  \
# mes                                                 1.000000  NaN
# Ano                                                      NaN  NaN
# O projeto já existe?                                     NaN  NaN
# Mídias Sociais                                           NaN  NaN
# P midia                                             0.118638  NaN
# Cobertura jornalística                                   NaN  NaN
# p cobertura                                         0.074678  NaN
# Matéria Site                                             NaN  NaN
# p materia                                           0.015926  NaN
# Adesivos Diversos                                        NaN  NaN
# p adesivo                                           0.077681  NaN
# Banner Digital                                           NaN  NaN
# p baner                                             0.045345  NaN
# ...

# %%
midias= levantamento[levantamento['Mídias Sociais'] ==1]

# %%
len(midias)
# Out:
# 130

# %%
a
# Out:
#     Envio do formulario data/hora   mes     Ano  \
# 0                      11/05/2018   5.0  2018.0
# 2                      04/06/2018   6.0  2018.0
# 5                      06/04/2018   4.0  2018.0
# 6                      11/04/2018   4.0  2018.0
# 7                      16/04/2018   4.0  2018.0
# 20                     21/05/2018   5.0  2018.0
# 25                     23/05/2018   5.0  2018.0
# 27                     30/05/2018   5.0  2018.0
# 29                     30/05/2018   5.0  2018.0
# 30                     30/05/2018   5.0  2018.0
# 31                     30/05/2018   5.0  2018.0
# 32                     30/05/2018   5.0  2018.0
# 33                     30/05/2018   5.0  2018.0
# 34                     30/05/2018   5.0  2018.0
# 35                     30/05/2018   5.0  2018.0
# 36                     30/05/2018   5.0  2018.0
# 37                     30/05/2018   5.0  2018.0
# 40                     30/05/2018   5.0  2018.0
# ...

# %%
plt.rcParams['figure.figsize'] = (10,10)
print(levantamento.boxplot(column='total'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
v =midias.groupby(['Unidade/Área operacional'])['Unidade/Área operacional'].value_counts()

# %%
v
# Out:
# Unidade/Área operacional  Unidade/Área operacional
# DEP                       DEP                          3
# DIOP                      DIOP                         1
# Faculdade Senac           Faculdade Senac             17
# GERCOM                    GERCOM                       4
# GRH                       GRH                          4
# SENAC/ Caruaru            SENAC/ Caruaru               4
# SENAC/ Garanhuns          SENAC/ Garanhuns            11
# SENAC/ Paulista           SENAC/ Paulista             11
# SENAC/ Petrolina          SENAC/ Petrolina            11
# SENAC/ Vitoria            SENAC/ Vitoria              12
# Senac/Serra Talhada       Senac/Serra Talhada          5
# UEP                       UEP                         21
# UHT                       UHT                         11
# UIP                       UIP                          5
# UIS                       UIS                          8
# UTIC                      UTIC                         2
# ...

# %%
v
# Out:
# Unidade/Área operacional  Unidade/Área operacional
# DEP                       DEP                          3
# DIOP                      DIOP                         1
# Faculdade Senac           Faculdade Senac             17
# GERCOM                    GERCOM                       4
# GRH                       GRH                          4
# SENAC/ Caruaru            SENAC/ Caruaru               4
# SENAC/ Garanhuns          SENAC/ Garanhuns            11
# SENAC/ Paulista           SENAC/ Paulista             11
# SENAC/ Petrolina          SENAC/ Petrolina            11
# SENAC/ Vitoria            SENAC/ Vitoria              12
# Senac/Serra Talhada       Senac/Serra Talhada          5
# UEP                       UEP                         21
# UHT                       UHT                         11
# UIP                       UIP                          5
# UIS                       UIS                          8
# UTIC                      UTIC                         2
# ...

# %%
midia= pd.DataFrame(v)

# %%
midia
# Out:
#                                                    Unidade/Área operacional
# Unidade/Área operacional Unidade/Área operacional
# DEP                      DEP                                              3
# DIOP                     DIOP                                             1
# Faculdade Senac          Faculdade Senac                                 17
# GERCOM                   GERCOM                                           4
# GRH                      GRH                                              4
# SENAC/ Caruaru           SENAC/ Caruaru                                   4
# SENAC/ Garanhuns         SENAC/ Garanhuns                                11
# SENAC/ Paulista          SENAC/ Paulista                                 11
# SENAC/ Petrolina         SENAC/ Petrolina                                11
# SENAC/ Vitoria           SENAC/ Vitoria                                  12
# Senac/Serra Talhada      Senac/Serra Talhada                              5
# ...

# %%
b =levantamento.groupby(['Unnamed: 53',"Endereço de e-mail"])['Endereço de e-mail'].count()

# %%
b
# Out:
# Unnamed: 53  Endereço de e-mail
# Eduardo      ElizabeteSaboia@pe.senac.br      19
#              anakarinesilva@pe.senac.br        2
#              aparecidasilva@pe.senac.br        1
#              carloseduardo@pe.senac.br         5
#              christianasantoro@pe.senac.br     1
#              christianegonzaga@pe.senac.br     1
#              cis-supervisao@pe.senac.br        1
#              claudeteantonia@pe.senac.br       2
#              cybellealmeida@pe.senac.br        1
#              edianezfigueiredo@pe.senac.br     1
#              eduardosimoes@pe.senac.br         1
#              elianefidelis@pe.senac.br         2
#              elizabetesaboia@pe.senac.br       1
#              gercomedu@gmail.com               2
#              isabelvieiar@pe.senac.br          1
#              manuelasilva@pe.senac.br          1
#              marciamiranda@pe.senac.br         2
#              marco-aurellio@hotmail.com        2
# ...

# %%
a =levantamento.groupby(['Unidade/Área operacional',"Endereço de e-mail"])['Endereço de e-mail'].count()

# %%
a
# Out:
# Unidade/Área operacional  Endereço de e-mail
# DAF                       nataliamolnar@pe.senac.br           1
# DEP                       GuiomarAlbuquerque@pe.senac.br      1
#                           LEDACAMPOS@PE.SENAC.BR              1
#                           alessandrasantana@pe.senac.br       2
#                           christianasantoro@pe.senac.br       1
#                           elianefidelis@pe.senac.br           3
#                           gercomedu@gmail.com                 1
#                           heloisagandolfi@pe.senac.br         1
#                           isabelvieiar@pe.senac.br            1
#                           ledacampos@pe.senac.br              2
#                           luizcosta@pe.senac.br               1
#                           marciamiranda@pe.senac.br           5
#                           nataliamolnar@pe.senac.br           5
#                           tacianacarvalho@pe.senac.br         2
# ...

# %%
plt.rcParams['figure.figsize'] = (10,10)
y = levantamento['total']
x = levantamento['Dias entre cadastro e finalização do serviço meta (<=7)']
 
# plot grafico de dispersao
#cruzando os dados de carga (h) e preço do curso
plt.scatter(x, y)

# %%
parceiros = pd.DataFrame(parceitos)

# %%
data
# Out:
#                                            Endereço de e-mail
# Unnamed: 53 Endereço de e-mail
# Eduardo     ElizabeteSaboia@pe.senac.br                    19
#             anakarinesilva@pe.senac.br                      2
#             aparecidasilva@pe.senac.br                      1
#             carloseduardo@pe.senac.br                       5
#             christianasantoro@pe.senac.br                   1
#             christianegonzaga@pe.senac.br                   1
#             cis-supervisao@pe.senac.br                      1
#             claudeteantonia@pe.senac.br                     2
#             cybellealmeida@pe.senac.br                      1
#             edianezfigueiredo@pe.senac.br                   1
#             eduardosimoes@pe.senac.br                       1
#             elianefidelis@pe.senac.br                       2
#             elizabetesaboia@pe.senac.br                     1
#             gercomedu@gmail.com                             2
# ...

# %%
parceitos = levantamento['Caso sim, quais são os parceiros']

# %%
Unidades_por_funcionario1 =levantamento.groupby(['Unnamed: 58', 'Unidade/Área operacional'])['Unnamed: 58'].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-0d65e3ea2435> in <module>()
# ----> 1 Unidades_por_funcionario1 =levantamento.groupby(['Unnamed: 58', 'Unidade/Área operacional'])['Unnamed: 58'].count()
#
# C:\Users\marconunes\Desktop\PYTHON\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    5160         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    5161                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 5162                        **kwargs)
#    5163
#    5164     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# C:\Users\marconunes\Desktop\PYTHON\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\pandas\core\groupby.py in groupby(obj, by, **kwds)
# ...

# %%
df = pd.DataFrame(Unidades_por_funcionario1)

# %%
parceiros.to_excel('parceiros.xls',index=True)

# %%
a.to_excel('planilha_pandas.xls',index=False)

# %%
a
# Out:
# Unidade/Área operacional  Endereço de e-mail
# DAF                       nataliamolnar@pe.senac.br           1
# DEP                       GuiomarAlbuquerque@pe.senac.br      1
#                           LEDACAMPOS@PE.SENAC.BR              1
#                           alessandrasantana@pe.senac.br       2
#                           christianasantoro@pe.senac.br       1
#                           elianefidelis@pe.senac.br           3
#                           gercomedu@gmail.com                 1
#                           heloisagandolfi@pe.senac.br         1
#                           isabelvieiar@pe.senac.br            1
#                           ledacampos@pe.senac.br              2
#                           luizcosta@pe.senac.br               1
#                           marciamiranda@pe.senac.br           5
#                           nataliamolnar@pe.senac.br           5
#                           tacianacarvalho@pe.senac.br         2
# ...

# %%
import xlwt

# %%
wb = xlwt.Workbook()

# %%
wb

# %%
wb.save('unidade_solocitante.xls')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-dba561062df5> in <module>()
# ----> 1 wb.save('unidade_solocitante.xls')
#
# C:\Users\marconunes\Desktop\PYTHON\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\xlwt\Workbook.py in save(self, filename_or_stream)
#     708
#     709         doc = CompoundDoc.XlsDoc()
# --> 710         doc.save(filename_or_stream, self.get_biff_data())
#     711
#     712
#
# C:\Users\marconunes\Desktop\PYTHON\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\xlwt\Workbook.py in get_biff_data(self)
#     678         eof = self.__eof_rec()
#     679
# --> 680         self.__worksheets[self.__active_sheet].selected = True
#     681         sheets = b''
#     682         sheet_biff_lens = []
#
# IndexError: list index out of range

# %%
  ws.write(i, 1+j, sequencia[j], styleA)

# %%
df = pd.read_excel(xlsx, 'unidade_solocitante')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-fbc30dec2d50> in <module>()
# ----> 1 df = pd.read_excel(xlsx, 'unidade_solocitante')
#
# NameError: name 'xlsx' is not defined

# %%
plt.rcParams['figure.figsize'] = (10,10)
levantamento['N° serviços do projeto'].value_counts().plot(kind='barh')

# %%
plt.rcParams['figure.figsize'] = (10,20)
ds.boxplot(column='Valor_Venda')
