# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
levantamento = pd.read_csv('prouni2016.CSV' ,delimiter=';' , encoding='ISO-8859-1')

# %%
levantamento.head(5)
# Out:
#    ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA  \
# 0                 2016                     20
# 1                 2016                     20
# 2                 2016                     20
# 3                 2016                     20
# 4                 2016                    423
#
#                                       NOME_IES_BOLSA         TIPO_BOLSA  \
# 0                        UNIVERSIDADE DE PASSO FUNDO  BOLSA PARCIAL 50%
# 1                        UNIVERSIDADE DE PASSO FUNDO     BOLSA INTEGRAL
# 2                        UNIVERSIDADE DE PASSO FUNDO  BOLSA PARCIAL 50%
# 3                        UNIVERSIDADE DE PASSO FUNDO  BOLSA PARCIAL 50%
# 4  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
#
#   MODALIDADE_ENSINO_BOLSA    NOME_CURSO_BOLSA NOME_TURNO_CURSO_BOLSA  \
# 0              PRESENCIAL       Administração                Noturno
# 1              PRESENCIAL       Administração                Noturno
# ...

# %%
levantamento.columns
# Out:
# Index(['ANO_CONCESSAO_BOLSA', 'CODIGO_EMEC_IES_BOLSA', 'NOME_IES_BOLSA',
#        'TIPO_BOLSA', 'MODALIDADE_ENSINO_BOLSA', 'NOME_CURSO_BOLSA',
#        'NOME_TURNO_CURSO_BOLSA', 'CPF_BENEFICIARIO_BOLSA',
#        'SEXO_BENEFICIARIO_BOLSA', 'RACA_BENEFICIARIO_BOLSA',
#        'DT_NASCIMENTO_BENEFICIARIO', 'BENEFICIARIO_DEFICIENTE_FISICO',
#        'REGIAO_BENEFICIARIO_BOLSA', 'SIGLA_UF_BENEFICIARIO_BOLSA',
#        'MUNICIPIO_BENEFICIARIO_BOLSA'],
#       dtype='object')

# %%
print("Quantidade de bolsas Registradas: ",len(levantamento))
# Out:
# Quantidade de bolsas Registradas:  239262

# %%
print("Distribuição de bolsas por Cursos")
levantamento['TIPO_BOLSA'].value_counts().plot(kind='barh')
# Out:
# Distribuição de bolsas por Cursos

# %%
print("Distribuição de bolsas por modalidade")
levantamento['MODALIDADE_ENSINO_BOLSA'].value_counts().plot(kind='barh')
# Out:
# Distribuição de bolsas por modalidade

# %%
print("Distribuição de bolsas por Cursos")
levantamento['NOME_CURSO_BOLSA'].value_counts().head(15).plot(kind='barh')
plt.rcParams['figure.figsize'] = (20,10)
# Out:
# Distribuição de bolsas por Cursos

# %%
levantamento['NOME_TURNO_CURSO_BOLSA'].value_counts().plot(kind='barh')

# %%
print("Distribuição de bolsas por sexo")
levantamento['SEXO_BENEFICIARIO_BOLSA'].value_counts().plot(kind='barh')
plt.rcParams['figure.figsize'] = (10,20)
# Out:
# Distribuição de bolsas por sexo

# %%
print("Distribuição de bolsas por raça")
levantamento['RACA_BENEFICIARIO_BOLSA'].value_counts().plot(kind='barh')
plt.rcParams['figure.figsize'] = (3,3)
# Out:
# Distribuição de bolsas por raça

# %%
levantamento['BENEFICIARIO_DEFICIENTE_FISICO'].value_counts()
# Out:
# NÃO    237492
# SIM      1770
# Name: BENEFICIARIO_DEFICIENTE_FISICO, dtype: int64

# %%
print("Distribuição de bolsas por estados")
levantamento['SIGLA_UF_BENEFICIARIO_BOLSA'].value_counts().plot(kind='barh')

plt.rcParams['figure.figsize'] = (20,30)
# Out:
# Distribuição de bolsas por estados

# %%
print("Distribuição de bolsas por região")
levantamento['REGIAO_BENEFICIARIO_BOLSA'].value_counts().plot(kind='barh')
plt.rcParams['figure.figsize'] = (2,10)
# Out:
# Distribuição de bolsas por região

# %%
#filtro pernambuco
ProuniPE =levantamento[levantamento['SIGLA_UF_BENEFICIARIO_BOLSA']== 'PE']

# %%
print("bolsas em Pernambuco: ",len(ProuniPE))
# Out:
# bolsas em Pernambuco:  8616

# %%
ProuniPE.head(5)
# Out:
#        ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA  \
# 11301                 2016                   2566
# 11302                 2016                   2566
# 11303                 2016                   2566
# 11304                 2016                   2566
# 11321                 2016                   2566
#
#                                NOME_IES_BOLSA      TIPO_BOLSA  \
# 11301  INSTITUTO DE ENSINO SUPERIOR DE OLINDA  BOLSA INTEGRAL
# 11302  INSTITUTO DE ENSINO SUPERIOR DE OLINDA  BOLSA INTEGRAL
# 11303  INSTITUTO DE ENSINO SUPERIOR DE OLINDA  BOLSA INTEGRAL
# 11304  INSTITUTO DE ENSINO SUPERIOR DE OLINDA  BOLSA INTEGRAL
# 11321  INSTITUTO DE ENSINO SUPERIOR DE OLINDA  BOLSA INTEGRAL
#
#       MODALIDADE_ENSINO_BOLSA NOME_CURSO_BOLSA NOME_TURNO_CURSO_BOLSA  \
# 11301              PRESENCIAL    Administração                Noturno
# 11302              PRESENCIAL    Administração                Noturno
# 11303              PRESENCIAL    Administração                Noturno
# ...

# %%
print("Distribuição de bolsas em PE")
ProuniPE['MUNICIPIO_BENEFICIARIO_BOLSA'].value_counts().head(20).plot(kind='barh')
plt.rcParams['figure.figsize'] = (5,20)
# Out:
# Distribuição de bolsas em PE

# %%
print("Distribuição de bolsas em PE peço curso")
ProuniPE['NOME_CURSO_BOLSA'].value_counts().head(20).plot(kind='barh')
plt.rcParams['figure.figsize'] = (10,20)
# Out:
# Distribuição de bolsas em PE peço curso

# %%
print("Distribuição de bolsas em PE")
ProuniPE['TIPO_BOLSA'].value_counts().head(20).plot(kind='barh')
plt.rcParams['figure.figsize'] = (1,1)
# Out:
# Distribuição de bolsas em PE

# %%
print("Distribuição de bolsas em PE por Instituições as 10 principais")
ProuniPE['NOME_IES_BOLSA'].value_counts().head(20).plot(kind='barh')
plt.rcParams['figure.figsize'] = (20,30)
# Out:
# Distribuição de bolsas em PE por Instituições as 10 principais

# %%
ProuniPE['NOME_IES_BOLSA'].unique()
# Out:
# array(['INSTITUTO DE ENSINO SUPERIOR DE OLINDA',
#        'UNIVERSIDADE PITÁGORAS UNOPAR', 'UNIVERSIDADE PAULISTA',
#        'CENTRO UNIVERSITÁRIO INTERNACIONAL',
#        'FACULDADE EDUCACIONAL DA LAPA',
#        'FACULDADE INTEGRADA DE PERNAMBUCO', 'FACULDADE BOA VIAGEM',
#        'UNIVERSIDADE ESTÁCIO DE SÁ',
#        'FACULDADE JOAQUIM NABUCO DE SÃO LOURENÇO DA MATA',
#        'UNIVERSIDADE CATÓLICA DE PERNAMBUCO',
#        'FACULDADE FRASSINETTI DO RECIFE', 'FOCCA - FACULDADE DE OLINDA',
#        'Faculdade Estácio do Recife - Estácio FIR',
#        'FACULDADE DE CIÊNCIAS HUMANAS DE PERNAMBUCO',
#        'FACULDADE SÃO MIGUEL', 'FACULDADE JOAQUIM NABUCO DO JANGA',
#        'FACULDADE ESCRITOR OSMAN DA COSTA LINS',
#        'CENTRO UNIVERSITÁRIO DO VALE DO IPOJUCA',
#        'FACULDADE DOS GUARARAPES', 'FACULDADE DA ESCADA',
#        'CENTRO UNIVERSITÁRIO TABOSA DE ALMEIDA',
#        'CENTRO UNIVERSITÁRIO MAURÍCIO DE NASSAU',
# ...

# %%
ProuniPE
# Out:
#         ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA  \
# 11301                  2016                   2566
# 11302                  2016                   2566
# 11303                  2016                   2566
# 11304                  2016                   2566
# 11321                  2016                   2566
# 14546                  2016                    298
# 14607                  2016                    298
# 14608                  2016                    298
# 14647                  2016                    298
# 14648                  2016                    298
# 14649                  2016                    298
# 14762                  2016                    298
# 14763                  2016                    298
# 14764                  2016                    298
# 14765                  2016                    298
# 14766                  2016                    298
# 14806                  2016                    298
# ...

# %%
prouni2016 = pd.read_csv('prouni2016.CSV' ,delimiter=';' , encoding='ISO-8859-1')
prouni2014 = pd.read_csv('prouni2014.CSV' ,delimiter=';' , encoding='ISO-8859-1')
prouni2010 = pd.read_csv('prouni2010.CSV' ,delimiter=';' , encoding='ISO-8859-1')

# %%
print(len(prouni2016))
print(len(prouni2014))
print(len(prouni2010))
# Out:
# 239262
# 223598
# 152733

# %%
data = {
    "Ano" :[2010,2014,2016],
    "Bolsas": [len(prouni2010),len(prouni2014),len(prouni2016)]
}

# %%
data
# Out:
# {'Ano': [2010, 2014, 2016], 'Bolsas': [152733, 223598, 239262]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     Ano  Bolsas
# 0  2010  152733
# 1  2014  223598
# 2  2016  239262

# %%
df.
