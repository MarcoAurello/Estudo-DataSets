# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
levantamento2013 = pd.read_csv('ocorrenciasmun-brasil2013.CSV' ,delimiter=';' , encoding='ISO-8859-1')
levantamento2014 = pd.read_csv('ocorrenciasmun-brasil2014.CSV' ,delimiter=';' , encoding='ISO-8859-1')
levantamento2015 = pd.read_csv('ocorrenciasmun-brasil2015.CSV' ,delimiter=';' , encoding='ISO-8859-1')

# %%
levantamento2015.head(10)
# Out:
#   Registros de Boletins de Ocorrências por munícipio e mês - 2015 Unnamed: 1  \
# 0  Fonte: SinespJC - Módulo Polícias Civis do Bra...                     NaN
# 1  Nota 1: As informações apresentadas estão de a...                     NaN
# 2  Nota 2: Por motivo de compactação do arquivo, ...                     NaN
# 3                                             Região                Sigla UF
# 4                                       CENTRO-OESTE                      DF
# 5                                       CENTRO-OESTE                      DF
# 6                                       CENTRO-OESTE                      DF
# 7                                       CENTRO-OESTE                      DF
# 8                                       CENTRO-OESTE                      DF
# 9                                       CENTRO-OESTE                      DF
#
#          Unnamed: 2             Unnamed: 3 Unnamed: 4  Unnamed: 5 Unnamed: 6  \
# ...

# %%
len(levantamento2013)
# Out:
# 60464

# %%
len(levantamento2014)
# Out:
# 52297

# %%
len(levantamento2015)
# Out:
# 65116

# %%
#exibindo quantidade de bolsas por periodo 
print('')
y_axis = [len(levantamento2013),len(levantamento2014),len(levantamento2015)]
x_axis = ['2013','2014','2015']
width_n = 0.4
bar_color = 'yellow'

plt.bar(x_axis, y_axis, width=width_n, color=bar_color)
plt.show()

# %%
levantamento2015['Unnamed: 6'].unique()
# Out:
# array([nan, 'Mês', '01', '02', '03', '04', '05', '06', '07', '08', '09',
#        '10', '11', '12'], dtype=object)

# %%
levRio2013 =levantamento2013[levantamento2013['Unnamed: 2'] =='Rio de Janeiro']
levRio2014 =levantamento2014[levantamento2014['Unnamed: 2'] =='Rio de Janeiro']
levRio2015 =levantamento2015[levantamento2015['Unnamed: 2'] =='Rio de Janeiro']

# %%
levRio2013Julho =levRio2013[levRio2013['Unnamed: 6'] =='07']
levRio2014Julho =levRio2014[levRio2014['Unnamed: 6'] =='07']
levRio2015Julho =levRio2015[levRio2015['Unnamed: 6'] =='07']

# %%
len(levRio2013Julho)
# Out:
# 231

# %%
len(levRio2014Julho)
# Out:
# 219

# %%
len(levRio2015Julho)
# Out:
# 214

# %%
levRio2014Julho['Unnamed: 5'].value_counts()
# Out:
# Furto de veículo                       64
# Estupro                                57
# Homicídio doloso                       47
# Roubo de veículo                       41
# Roubo seguido de morte (latrocínio)     8
# Lesão corporal seguida de morte         2
# Name: Unnamed: 5, dtype: int64

# %%
levRio2013Julho['Unnamed: 5'].value_counts()
# Out:
# Estupro                                63
# Furto de veículo                       63
# Roubo de veículo                       54
# Homicídio doloso                       44
# Roubo seguido de morte (latrocínio)     6
# Lesão corporal seguida de morte         1
# Name: Unnamed: 5, dtype: int64

# %%
levRio2013
# Out:
#       Registros de Boletins de Ocorrências por munícipio e mês - 2013  \
# 34236                                            SUDESTE
# 34237                                            SUDESTE
# 34238                                            SUDESTE
# 34239                                            SUDESTE
# 34240                                            SUDESTE
# 34241                                            SUDESTE
# 34242                                            SUDESTE
# 34243                                            SUDESTE
# 34244                                            SUDESTE
# 34245                                            SUDESTE
# 34246                                            SUDESTE
# 34247                                            SUDESTE
# 34248                                            SUDESTE
# 34249                                            SUDESTE
# 34250                                            SUDESTE
# ...

# %%
ds =levRio2013Julho.groupby(['Unnamed: 5'])['Unnamed: 8'].sum()
ds
# Out:
# Unnamed: 5
# Estupro                                5711129211172112721943715616511710827122193122...
# Furto de veículo                       1031714147111161392121841322161512515720114121...
# Homicídio doloso                       4111169211213514321428232121023011223117612125...
# Lesão corporal seguida de morte                                                        1
# Roubo de veículo                       4612181272110112312579126161132131926641531173...
# Roubo seguido de morte (latrocínio)                                               111161
# Name: Unnamed: 8, dtype: object

# %%
levRio2013Julho.dtypes
# Out:
# Registros de Boletins de Ocorrências por munícipio e mês - 2013    object
# Unnamed: 1                                                         object
# Unnamed: 2                                                         object
# Unnamed: 3                                                         object
# Unnamed: 4                                                         object
# Unnamed: 5                                                         object
# Unnamed: 6                                                         object
# Unnamed: 7                                                         object
# Unnamed: 8                                                         object
# dtype: object

# %%
levRio2013Julho['Unnamed: 8'] = levRio2013Julho['Unnamed: 8'].astype('float64')
levRio2014Julho['Unnamed: 8'] = levRio2014Julho['Unnamed: 8'].astype('float64')
levRio2015Julho['Unnamed: 8'] = levRio2015Julho['Unnamed: 8'].astype('float64')
# Out:
# C:\Users\marconunes\Desktop\PYTHON\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\marconunes\Desktop\PYTHON\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# ...

# %%
levRio2013Julho.dtypes
# Out:
# Registros de Boletins de Ocorrências por munícipio e mês - 2013     object
# Unnamed: 1                                                          object
# Unnamed: 2                                                          object
# Unnamed: 3                                                          object
# Unnamed: 4                                                          object
# Unnamed: 5                                                          object
# Unnamed: 6                                                          object
# Unnamed: 7                                                          object
# Unnamed: 8                                                         float64
# dtype: object

# %%
levRio2014Julho.dtypes
# Out:
# Registros de Boletins de Ocorrências por munícipio e mês - 2014     object
# Unnamed: 1                                                          object
# Unnamed: 2                                                          object
# Unnamed: 3                                                          object
# Unnamed: 4                                                          object
# Unnamed: 5                                                          object
# Unnamed: 6                                                          object
# Unnamed: 7                                                          object
# Unnamed: 8                                                         float64
# dtype: object

# %%
levRio2015Julho.dtypes
# Out:
# Registros de Boletins de Ocorrências por munícipio e mês - 2015     object
# Unnamed: 1                                                          object
# Unnamed: 2                                                          object
# Unnamed: 3                                                          object
# Unnamed: 4                                                          object
# Unnamed: 5                                                          object
# Unnamed: 6                                                          object
# Unnamed: 7                                                          object
# Unnamed: 8                                                         float64
# dtype: object

# %%
print('ocorrencias no RJ em julho 2013')
ocorrenciaRioJul13 =levRio2013Julho.groupby(['Unnamed: 5'])['Unnamed: 8'].sum()
ocorrenciaRioJul13
# Out:
# ocorrencias no RJ em julho 2013
# Unnamed: 5
# Estupro                                 441.0
# Furto de veículo                       1501.0
# Homicídio doloso                        289.0
# Lesão corporal seguida de morte           1.0
# Roubo de veículo                       2242.0
# Roubo seguido de morte (latrocínio)      11.0
# Name: Unnamed: 8, dtype: float64

# %%
ocorrenciaRioJul13.plot(kind='barh')
plt.rcParams['figure.figsize'] = (18,5)

# %%
print('ocorrencias no RJ em julho 2014')
ocorrenciaRioJul14 =levRio2014Julho.groupby(['Unnamed: 5'])['Unnamed: 8'].sum()
ocorrenciaRioJul14
# Out:
# ocorrencias no RJ em julho 2014
# Unnamed: 5
# Estupro                                 402.000
# Furto de veículo                       1456.000
# Homicídio doloso                        343.000
# Lesão corporal seguida de morte           4.000
# Roubo de veículo                       1479.001
# Roubo seguido de morte (latrocínio)      13.000
# Name: Unnamed: 8, dtype: float64

# %%
ocorrenciaRioJul14.plot(kind='barh')
plt.rcParams['figure.figsize'] = (18,5)

# %%
print('ocorrencias no RJ em julho 2015')
ocorrenciaRioJul15 =levRio2015Julho.groupby(['Unnamed: 5'])['Unnamed: 8'].sum()
ocorrenciaRioJul15
# Out:
# ocorrencias no RJ em julho 2015
# Unnamed: 5
# Estupro                                 377.000
# Furto de veículo                       1381.000
# Homicídio doloso                        290.000
# Lesão corporal seguida de morte           2.000
# Roubo de veículo                       1250.176
# Roubo seguido de morte (latrocínio)       9.000
# Name: Unnamed: 8, dtype: float64

# %%
ocorrenciaRioJul15.plot(kind='barh')
plt.rcParams['figure.figsize'] = (18,5)

# %%
levRio2014Junho =levRio2014[levRio2014['Unnamed: 6'] =='06']
levRio2014Agosto =levRio2014[levRio2014['Unnamed: 6'] =='08']

# %%
levRio2014Junho.head(2)
# Out:
#       Registros de Boletins de Ocorrências por munícipio e mês - 2014  \
# 25313                                            SUDESTE
# 25325                                            SUDESTE
#
#       Unnamed: 1      Unnamed: 2 Unnamed: 3      Unnamed: 4        Unnamed: 5  \
# 25313         RJ  Rio de Janeiro    3300100  Angra Dos Reis           Estupro
# 25325         RJ  Rio de Janeiro    3300100  Angra Dos Reis  Furto de veículo
#
#       Unnamed: 6 Unnamed: 7 Unnamed: 8
# 25313         06    06/2014          8
# 25325         06    06/2014         12

# %%
levRio2014Agosto.head(2)
# Out:
#       Registros de Boletins de Ocorrências por munícipio e mês - 2014  \
# 25315                                            SUDESTE
# 25327                                            SUDESTE
#
#       Unnamed: 1      Unnamed: 2 Unnamed: 3      Unnamed: 4        Unnamed: 5  \
# 25315         RJ  Rio de Janeiro    3300100  Angra Dos Reis           Estupro
# 25327         RJ  Rio de Janeiro    3300100  Angra Dos Reis  Furto de veículo
#
#       Unnamed: 6 Unnamed: 7 Unnamed: 8
# 25315         08    08/2014          8
# 25327         08    08/2014         12

# %%
levRio2014Junho['Unnamed: 8'] = levRio2014Junho['Unnamed: 8'].astype('float64')
levRio2014Agosto['Unnamed: 8'] = levRio2014Agosto['Unnamed: 8'].astype('float64')
# Out:
# C:\Users\marconunes\Desktop\PYTHON\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\marconunes\Desktop\PYTHON\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
print('ocorrencias no RJ em junho 2014')
ocorrenciaRioJun14 =levRio2014Junho.groupby(['Unnamed: 5'])['Unnamed: 8'].sum()
ocorrenciaRioJun14
# Out:
# ocorrencias no RJ em junho 2014
# Unnamed: 5
# Estupro                                 393.000
# Furto de veículo                       1391.000
# Homicídio doloso                        360.000
# Lesão corporal seguida de morte           1.000
# Roubo de veículo                       1602.034
# Roubo seguido de morte (latrocínio)      16.000
# Name: Unnamed: 8, dtype: float64

# %%
print('ocorrencias no RJ em Agosto 2014')
ocorrenciaRioAgo14 =levRio2014Agosto.groupby(['Unnamed: 5'])['Unnamed: 8'].sum()
ocorrenciaRioAgo14
# Out:
# ocorrencias no RJ em Agosto 2014
# Unnamed: 5
# Estupro                                 404.000
# Furto de veículo                       1493.000
# Homicídio doloso                        349.000
# Lesão corporal seguida de morte           3.000
# Roubo de veículo                       1410.002
# Roubo seguido de morte (latrocínio)       9.000
# Name: Unnamed: 8, dtype: float64

# %%
ocorrenciaRioJun14.plot(kind='barh')
plt.rcParams['figure.figsize'] = (18,5)

# %%
ocorrenciaRioJul14.plot(kind='barh')
plt.rcParams['figure.figsize'] = (18,5)

# %%
ocorrenciaRioAgo14.plot(kind='barh')
plt.rcParams['figure.figsize'] = (18,5)

# %%
levRio2013Julho
# Out:
#       Registros de Boletins de Ocorrências por munícipio e mês - 2013  \
# 34241                                            SUDESTE
# 34253                                            SUDESTE
# 34265                                            SUDESTE
# 34274                                            SUDESTE
# 34289                                            SUDESTE
# 34300                                            SUDESTE
# 34312                                            SUDESTE
# 34335                                            SUDESTE
# 34349                                            SUDESTE
# 34360                                            SUDESTE
# 34371                                            SUDESTE
# 34380                                            SUDESTE
# 34389                                            SUDESTE
# 34397                                            SUDESTE
# 34404                                            SUDESTE
# ...

# %%
ds
# Out:
# Unnamed: 5
# Estupro                                5711129211172112721943715616511710827122193122...
# Furto de veículo                       1031714147111161392121841322161512515720114121...
# Homicídio doloso                       4111169211213514321428232121023011223117612125...
# Lesão corporal seguida de morte                                                        1
# Roubo de veículo                       4612181272110112312579126161132131926641531173...
# Roubo seguido de morte (latrocínio)                                               111161
# Name: Unnamed: 8, dtype: object

# %%
levRio2014Dez =levRio2014[levRio2014['Unnamed: 6'] =='12']

# %%
len(levRio2014Dez)
# Out:
# 224

# %%
len(levRio2014Julho)
# Out:
# 219

# %%
levRio2014Dez['Unnamed: 8'] = levRio2014Dez['Unnamed: 8'].astype('float64')
# Out:
# C:\Users\marconunes\Desktop\PYTHON\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
print('ocorrencias no RJ em desembro 2014')
ocorrenciaRioDes14 =levRio2014Dez.groupby(['Unnamed: 5'])['Unnamed: 8'].sum()
ocorrenciaRioDes14
# Out:
# ocorrencias no RJ em desembro 2014
# Unnamed: 5
# Estupro                                 395.000
# Furto de veículo                       1426.000
# Homicídio doloso                        384.000
# Lesão corporal seguida de morte           5.000
# Roubo de veículo                       1565.266
# Roubo seguido de morte (latrocínio)      16.000
# Name: Unnamed: 8, dtype: float64

# %%
levRio2014Dez
# Out:
#       Registros de Boletins de Ocorrências por munícipio e mês - 2014  \
# 25319                                            SUDESTE
# 25331                                            SUDESTE
# 25343                                            SUDESTE
# 25355                                            SUDESTE
# 25378                                            SUDESTE
# 25390                                            SUDESTE
# 25402                                            SUDESTE
# 25415                                            SUDESTE
# 25416                                            SUDESTE
# 25445                                            SUDESTE
# 25452                                            SUDESTE
# 25462                                            SUDESTE
# 25478                                            SUDESTE
# 25485                                            SUDESTE
# 25499                                            SUDESTE
# ...

# %%
levasntamentoLocalIncidenteRioDez14 =levRio2014Dez.groupby(['Unnamed: 4','Unnamed: 5']).aggregate({'Unnamed: 8': [max]})

# %%
levasntamentoLocalIncidenteRioDez14
# Out:
#                                                                   Unnamed: 8
#                                                                          max
# Unnamed: 4                    Unnamed: 5
# Angra Dos Reis                Estupro                                    7.0
#                               Furto de veículo                           8.0
#                               Homicídio doloso                          10.0
#                               Roubo de veículo                           6.0
# Araruama                      Estupro                                    3.0
#                               Furto de veículo                           8.0
#                               Homicídio doloso                           4.0
#                               Roubo de veículo                           2.0
#                               Roubo seguido de morte (latrocínio)        1.0
# Armação Dos Búzios            Furto de veículo                           9.0
# ...
