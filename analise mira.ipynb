# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ds= pd.read_csv('dados.csv' , delimiter=';', encoding='latin-1')

# %%
len(ds)
# Out:
# 38526

# %%
ds
# Out:
#        DR  Codigo Curso  Clas. Orcamentária  \
# 0      PE             9              24.443
# 1      PE             9              24.443
# 2      PE             9              24.443
# 3      PE             9              24.443
# 4      PE             9              24.443
# 5      PE             9              24.443
# 6      PE             9              24.443
# 7      PE             9              24.443
# 8      PE             9              24.443
# 9      PE             9              24.443
# 10     PE             9              24.443
# 11     PE             9              24.443
# 12     PE             9              24.443
# 13     PE             9              24.443
# 14     PE             9              24.443
# 15     PE             9              24.443
# 16     PE             9              24.443
# 17     PE           762              33.807
# 18     PE           762              33.807
# 19     PE           762              33.807
# ...

# %%
plt.rcParams['figure.figsize'] = (10,10)
ds['Unidade Operativa'].value_counts().plot(kind='barh')

# %%
plt.rcParams['figure.figsize'] = (10,10)
ds['Tipo Curso'].value_counts().plot(kind='barh')

# %%
plt.rcParams['figure.figsize'] = (10,10)
ds['Segmento'].value_counts().plot(kind='barh')

# %%
ds
# Out:
#        DR  Codigo Curso  Clas. Orcamentária  \
# 0      PE             9              24.443
# 1      PE             9              24.443
# 2      PE             9              24.443
# 3      PE             9              24.443
# 4      PE             9              24.443
# 5      PE             9              24.443
# 6      PE             9              24.443
# 7      PE             9              24.443
# 8      PE             9              24.443
# 9      PE             9              24.443
# 10     PE             9              24.443
# 11     PE             9              24.443
# 12     PE             9              24.443
# 13     PE             9              24.443
# 14     PE             9              24.443
# 15     PE             9              24.443
# 16     PE             9              24.443
# 17     PE           762              33.807
# 18     PE           762              33.807
# 19     PE           762              33.807
# ...

# %%
plt.rcParams['figure.figsize'] = (10,10)
ds['Modalidade Recurso'].value_counts().plot(kind='barh')

# %%
ds.dtypes
# Out:
# DR                                object
# Codigo Curso                       int64
# Clas. Orcamentária               float64
# Unidade Operativa                 object
# Condição                          object
# Tipo  Turma                       object
# ID Tipo Curso                      int64
# Tipo Curso                        object
# Segmento                          object
# Modalidade Recurso                object
# Eixo                              object
# Código da Turma Mira              object
# Código da Turma                    int64
# Ano da Turma                       int64
# Unidade da Turma                   int64
# Sigla                             object
# Curso                             object
# Situação                          object
# Sigla Situação                    object
# Novo Modelo?                      object
# Plano Nacional?                   object
# Início Turma                      object
# Final Turma                       object
# ...

# %%
plt.style.use('ggplot')

# %%
plt.rcParams['figure.figsize'] = (10,20)
ds.boxplot(column='Valor_Venda')

# %%
plt.rcParams['figure.figsize'] = (10,30)
ds['Local'].value_counts().plot(kind='barh').head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-07ea0af82336> in <module>()
#       1 plt.rcParams['figure.figsize'] = (10,30)
# ----> 2 ds['Local'].value_counts().plot(kind='barh').head(10)
#
# AttributeError: 'AxesSubplot' object has no attribute 'head'

# %%
plt.rcParams['figure.figsize'] = (10,30)
ds['CH Senac Mês'].value_counts().plot(kind='barh')
